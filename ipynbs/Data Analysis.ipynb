# %%
import pandas as pd
import numpy as np
from itertools import product

# %%
scenes = ['H','A','S','T','U','V','W','X','Y','Z']
'''
data = pd.DataFrame(columns=scenes)

df1 = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/scene-data/H-count.csv', header=None,
                names=['File'])
#df1 = df1.set_index('File')
df2 = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/scene-data/A-count.csv', header=None,
                names=['File', 'Scene', 'Number of Spikes', 'Number of Non-Spikes', 'Total Scenes'])
#df2 = df2.set_index('File')
df3 = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/scene-data/S-count.csv', header=None,
                names=['File'])
df3 = df3.set_index('File')
df4 = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/scene-data/T-count.csv', header=None,
                names=['File', 'Scene', 'Number of Spikes', 'Number of Non-Spikes', 'Total Scenes'])
df4 = df4.set_index('File')
df5 = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/scene-data/U-count.csv', header=None,
                names=['File'])
df5 = df5.set_index('File')
df6 = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/scene-data/V-count.csv', header=None,
                names=['File', 'Scene', 'Number of Spikes', 'Number of Non-Spikes', 'Total Scenes'])
df6 = df6.set_index('File')
df7 = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/scene-data/W-count.csv', header=None,
                names=['File'])
df7 = df7.set_index('File')
df8 = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/scene-data/X-count.csv', header=None,
                names=['File', 'Scene', 'Number of Spikes', 'Number of Non-Spikes', 'Total Scenes'])
df8 = df8.set_index('File')
df9 = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/scene-data/Y-count.csv', header=None,
                names=['File'])
df9 = df9.set_index('File')
df10 = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/scene-data/Z-count.csv', header=None,
                names=['File', 'Scene', 'Number of Spikes', 'Number of Non-Spikes', 'Total Scenes'])
df10 = df10.set_index('File')
df10
'''
#frames = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]
#result = pd.merge(df1,df2, on='File')
#result

df = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/test.csv', header=None, usecols=range(1,31))
cols = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/test.csv', header=None, usecols=range(0,1))

df = df.set_index(cols[0])
df.index.name = 'Files'
mi = zip(*product(scenes,['Number of Spikes', 'Total Scenes', 'Percent Spikes']))
#mi = zip(*product(range(8),['raw_count','count_dev','corrected_count','resistance','temperature']))
df.columns = pd.MultiIndex.from_arrays(mi,names=['Scene', 'Data'])
df
# Out:
# Scene                       H                                            A  \
# Data         Number of Spikes Total Scenes Percent Spikes Number of Spikes
# Files
# 150222B1.CXS                0          442       0.000000                0
# 150222B2.CXS                0          442       0.000000                0
# 150222F1.CXS                0          442       0.000000                0
# 150222F2.CXS                0          442       0.000000                0
# 150223B1.CXS                0           82       0.000000                0
# 150223B2.CXS                0           82       0.000000                0
# 150223F1.CXS                0           82       0.000000                0
# 150223F2.CXS                0           82       0.000000                0
# 150224B1.CXS                0          446       0.000000                0
# 150224B2.CXS                0          446       0.000000                0
# ...

# %%
df = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/combined-scenes.csv', header=None,
                names=['File', 'Number of Spikes', 'Total Scenes', 'Percentage Spikes'])
df = df.set_index('File')
df
# Out:
#               Number of Spikes  Total Scenes  Percentage Spikes
# File
# 150222B1.CXS                 0          4411           0.000000
# 150222B2.CXS                 0          4411           0.000000
# 150222F1.CXS                 0          4411           0.000000
# 150222F2.CXS                 0          4411           0.000000
# 150223B1.CXS                 0           819           0.000000
# 150223B2.CXS                 0           819           0.000000
# 150223F1.CXS                 0           819           0.000000
# 150223F2.CXS                 0           819           0.000000
# 150224B1.CXS                 0          4460           0.000000
# 150224B2.CXS                 0          4460           0.000000
# 150224F1.CXS                 0          4460           0.000000
# 150224F2.CXS                 0          4460           0.000000
# 150225B1.CXS                27          4448           0.006070
# 150225B2.CXS                14          4448           0.003147
# ...

# %%
from dateutil.parser import parse
import datetime
    
b1 = []
for i in range(0,1400,4):
    b1.append(df.ix[i])
b2 = []
for i in range(1,1400,4):
    b2.append(df.ix[i])
f1=[]
for i in range(2,1400,4):
    f1.append(df.ix[i])
f2=[]
for i in range(3,1400,4):
    f2.append(df.ix[i])

dates = []
b1df = pd.DataFrame(b1); b2df = pd.DataFrame(b2); f1df = pd.DataFrame(f1); f2df = pd.DataFrame(f2);
for i in b1df.index:
    dates.append(parse(i[:6]))
print len(dates)
b1df['Percentage Spikes']
# Out:
# 350
# 150222B1.CXS    0.000000
# 150223B1.CXS    0.000000
# 150224B1.CXS    0.000000
# 150225B1.CXS    0.006070
# 150226B1.CXS    0.073722
# 150227B1.CXS    0.070789
# 150228B1.CXS    0.068330
# 150301B1.CXS    0.073857
# 150302B1.CXS    0.075391
# 150303B1.CXS    0.077113
# 150304B1.CXS    0.082864
# 150305B1.CXS    0.081578
# 150306B1.CXS    0.071060
# 150307B1.CXS    0.039656
# 150308B1.CXS    0.059417
# 150309B1.CXS    0.068135
# 150310B1.CXS    0.099156
# 150311B1.CXS    0.057420
# 150312B1.CXS    0.059468
# 150313B1.CXS    0.062682
# 150314B1.CXS    0.064393
# 150315B1.CXS    0.069416
# 150316B1.CXS    0.070049
# 150317B1.CXS    0.068465
# 150318B1.CXS    0.068063
# 150319B1.CXS    0.076107
# 150320B1.CXS    0.074468
# 150321B1.CXS    0.064871
# 150322B1.CXS    0.062346
# 150323B1.CXS    0.048583
#                   ...
# 160114B1.CXS    0.205363
# 160115B1.CXS    0.185874
# 160116B1.CXS    0.211258
# 160117B1.CXS    0.215025
# 160118B1.CXS    0.187136
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %pylab inline
rcParams['figure.figsize'] = (35,35)

fig = plt.figure()

ax1 = fig.add_subplot(411)
ax2 = fig.add_subplot(412, sharex=ax1)
ax3 = fig.add_subplot(413, sharex=ax1)
ax4 = fig.add_subplot(414, sharex=ax1)

ax1.plot(dates, b1df['Percentage Spikes']*100)
ax2.plot(dates, b2df['Percentage Spikes']*100)
ax3.plot(dates, f1df['Percentage Spikes']*100)
ax4.plot(dates, f2df['Percentage Spikes']*100)

ax1.set_title('Channel B1', size=24); ax1.set_ylabel('% Data w/ Spikes', size=20); ax1.set_xlabel('Date', size=20)
ax2.set_title('Channel B2', size=24); ax2.set_ylabel('% Data w/ Spikes', size=20); ax2.set_xlabel('Date', size=20)
ax3.set_title('Channel F1', size=24); ax3.set_ylabel('% Data w/ Spikes', size=20); ax3.set_xlabel('Date', size=20)
ax4.set_title('Channel F2', size=24); ax4.set_ylabel('% Data w/ Spikes', size=20); ax4.set_xlabel('Date', size=20)

ax1.grid(True)
ax2.grid(True)
ax3.grid(True)
ax4.grid(True)

fig.suptitle('AERI SGP-C1 Spiked Radiance Data', fontsize=28, fontweight='bold', horizontalalignment='center',y=.94)
#ax1.annotate('Power Outage', (mdates.date2num(dates[308]),b1df['Percentage Spikes'][308]), xytext=(15,15),
             #textcoords='offset points', arrowprops=dict(arrowstyle='-|>'))

plt.savefig('/Users/lstefanski/aeri_data/sgp-c1-errors/aeri-sgpc1-spiked-data.png')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
# %pylab inline
rcParams['figure.figsize'] = (40,40)

fig = plt.figure()
ax1 = fig.add_subplot(411)
ax2 = fig.add_subplot(412, sharex=ax1)
ax3 = fig.add_subplot(413, sharex=ax1)
ax4 = fig.add_subplot(414, sharex=ax1)

for i in scenes:
    ax1.plot(dates, b1df[i]['Percentage Spikes']*100)
    ax2.plot(dates, b2df[i]['Percentage Spikes']*100)
    ax3.plot(dates, f1df[i]['Percentage Spikes']*100)
    ax4.plot(dates, f2df[i]['Percentage Spikes']*100)
legend = ['Scene ' + i for i in scenes]
    
ax1.legend(legend); ax1.set_title('Channel B1'); ax1.set_ylabel('% Data w/ Spikes'); ax1.set_xlabel('Time')
ax2.legend(legend); ax2.set_title('Channel B2'); ax2.set_ylabel('% Data w/ Spikes'); ax2.set_xlabel('Time')
ax3.legend(legend); ax3.set_title('Channel F1'); ax3.set_ylabel('% Data w/ Spikes'); ax3.set_xlabel('Time')
ax4.legend(legend); ax4.set_title('Channel F2'); ax4.set_ylabel('% Data w/ Spikes'); ax4.set_xlabel('Time')
medb1 = pd.DataFrame.mean(b1df.T.iloc[[i for i in range(2,30,3)]].T)
medsb1 = [np.mean(medb1)]*350
#ax1.plot(dates,medsb1)
#medb1
plt.savefig('/Users/lstefanski/aeri_data/sgp-c1-errors/plots.png')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['legend']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
df = pd.read_csv('/Users/lstefanski/aeri_data/sgp-c1-errors/combined-scenes.csv', header=None,
                names=['File', 'Number of Spikes', 'Total Scenes', 'Percentage Spikes'])
df = df.set_index('File')
df
# Out:
#               Number of Spikes  Total Scenes Percentage Spikes
# File
# 150222B1.CXS                 0          4411                 0
# 150222B2.CXS                 0          4411                 0
# 150222F1.CXS                 0          4411                 0
# 150222F2.CXS                 0          4411                 0
# 150223B1.CXS                 0           819                 0
# 150223B2.CXS                 0           819                 0
# 150223F1.CXS                 0           819                 0
# 150223F2.CXS                 0           819                 0
# 150224B1.CXS                 0          4460                 0
# 150224B2.CXS                 0          4460                 0
# 150224F1.CXS                 0          4460                 0
# 150224F2.CXS                 0          4460                 0
# 150225B1.CXS                27          4448       0.006070144
# 150225B2.CXS                14          4448       0.003147482
# ...

# %%
# Out:
# 1416
